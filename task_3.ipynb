# %%
# !pip install ultralytics -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 877.5/877.5 kB 47.8 MB/s eta 0:00:00

# %%
# !yolo detect predict model=yolov8m.pt source="/content/vehicles.mp4"
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100% 49.7M/49.7M [00:00<00:00, 87.0MB/s]
# Ultralytics 8.3.22 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8m summary (fused): 218 layers, 25,886,080 parameters, 0 gradients, 78.9 GFLOPs
#
# video 1/1 (frame 1/223) /content/vehicles.mp4: 384x640 (no detections), 112.4ms
# video 1/1 (frame 2/223) /content/vehicles.mp4: 384x640 2 persons, 1 bicycle, 1 car, 1 bus, 1 truck, 25.4ms
# video 1/1 (frame 3/223) /content/vehicles.mp4: 384x640 2 persons, 1 bicycle, 1 car, 1 bus, 1 truck, 25.3ms
# video 1/1 (frame 4/223) /content/vehicles.mp4: 384x640 2 persons, 1 bicycle, 2 cars, 1 bus, 25.3ms
# ...

# %%
# !ffmpeg -i {"/content/runs/detect/predict/vehicles.mp4"} -vcodec libx264 {"finalvid.mp4"}
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...
